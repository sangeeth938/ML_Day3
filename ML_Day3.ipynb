# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeeth938/ML_Day3/blob/main/ML_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **IPL Dataset Analysis**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data= pd.read_csv("/content/ipl_matches.csv")

# %%
data
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
data.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
data.tail()
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [5 rows x 18 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]>

# %%
data.shape
# Out:
# (636, 18)

# %%
data.describe()
# Out:
#                id       season  ...  win_by_wickets  umpire3
# count  636.000000   636.000000  ...      636.000000      0.0
# mean   318.500000  2012.490566  ...        3.372642      NaN
# std    183.741666     2.773026  ...        3.420338      NaN
# min      1.000000  2008.000000  ...        0.000000      NaN
# 25%    159.750000  2010.000000  ...        0.000000      NaN
# 50%    318.500000  2012.000000  ...        4.000000      NaN
# 75%    477.250000  2015.000000  ...        7.000000      NaN
# max    636.000000  2017.000000  ...       10.000000      NaN
#
# [8 rows x 6 columns]

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
data.notnull().sum()
# Out:
# id                 636
# season             636
# city               629
# date               636
# team1              636
# team2              636
# toss_winner        636
# toss_decision      636
# result             636
# dl_applied         636
# winner             633
# win_by_runs        636
# win_by_wickets     636
# player_of_match    633
# venue              636
# umpire1            635
# umpire2            635
# umpire3              0
# dtype: int64

# %%
#creating heat map using null values

sns.heatmap(data.isnull(),cmap="Blues")

# %%
sns.heatmap(data.notnull())

# %%
sns.heatmap(data.isnull(),cmap="Accent_r")

# %%
#Lets write cmap some error value and find what values can be fit into it

sns.heatmap(data.isnull(),cmap="Green")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-be45ee91154e> in <module>()
#       1 #Lets write cmap some error value and find what values can be fit into it
#       2
# ----> 3 sns.heatmap(data.isnull(),cmap="Green")
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     535     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
data.isnull()
# Out:
#         id  season   city   date  ...  venue  umpire1  umpire2  umpire3
# 0    False   False  False  False  ...  False    False    False     True
# 1    False   False  False  False  ...  False    False    False     True
# 2    False   False  False  False  ...  False    False    False     True
# 3    False   False  False  False  ...  False    False    False     True
# 4    False   False  False  False  ...  False     True     True     True
# ..     ...     ...    ...    ...  ...    ...      ...      ...      ...
# 631  False   False  False  False  ...  False    False    False     True
# 632  False   False  False  False  ...  False    False    False     True
# 633  False   False  False  False  ...  False    False    False     True
# 634  False   False  False  False  ...  False    False    False     True
# 635  False   False  False  False  ...  False    False    False     True
#
# [636 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
data
# Out:
#       id  season  ...          umpire1          umpire2
# 0      1    2017  ...      AY Dandekar         NJ Llong
# 1      2    2017  ...   A Nand Kishore           S Ravi
# 2      3    2017  ...      Nitin Menon        CK Nandan
# 3      4    2017  ...     AK Chaudhary    C Shamshuddin
# 4      5    2017  ...              NaN              NaN
# ..   ...     ...  ...              ...              ...
# 631  632    2016  ...   A Nand Kishore     BNJ Oxenford
# 632  633    2016  ...     AK Chaudhary  HDPK Dharmasena
# 633  634    2016  ...        M Erasmus    C Shamshuddin
# 634  635    2016  ...        M Erasmus        CK Nandan
# 635  636    2016  ...  HDPK Dharmasena     BNJ Oxenford
#
# [636 rows x 17 columns]

# %%
data1=pd.read_csv("/content/ipl_matches.csv")

# %%
data1
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
print(data1)
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
data1.drop("umpire3",axis=1,inplace=True)

# %%
print(data1)
# Out:
#       id  season  ...          umpire1          umpire2
# 0      1    2017  ...      AY Dandekar         NJ Llong
# 1      2    2017  ...   A Nand Kishore           S Ravi
# 2      3    2017  ...      Nitin Menon        CK Nandan
# 3      4    2017  ...     AK Chaudhary    C Shamshuddin
# 4      5    2017  ...              NaN              NaN
# ..   ...     ...  ...              ...              ...
# 631  632    2016  ...   A Nand Kishore     BNJ Oxenford
# 632  633    2016  ...     AK Chaudhary  HDPK Dharmasena
# 633  634    2016  ...        M Erasmus    C Shamshuddin
# 634  635    2016  ...        M Erasmus        CK Nandan
# 635  636    2016  ...  HDPK Dharmasena     BNJ Oxenford
#
# [636 rows x 17 columns]

# %%
data.shape
# Out:
# (636, 17)

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (625, 17)

# %%
data["season"].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
data["season"].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2016    60
# 2010    60
# 2017    58
# 2008    58
# 2015    57
# 2009    57
# 2014    53
# Name: season, dtype: int64

# %%
data
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]

# %%
print(data)
data.drop("umpire3",axis=1,inplace=True)
print(data)
# Out:
#       id  season       city  ...          umpire1          umpire2 umpire3
# 0      1    2017  Hyderabad  ...      AY Dandekar         NJ Llong     NaN
# 1      2    2017       Pune  ...   A Nand Kishore           S Ravi     NaN
# 2      3    2017     Rajkot  ...      Nitin Menon        CK Nandan     NaN
# 3      4    2017     Indore  ...     AK Chaudhary    C Shamshuddin     NaN
# 4      5    2017  Bangalore  ...              NaN              NaN     NaN
# ..   ...     ...        ...  ...              ...              ...     ...
# 631  632    2016     Raipur  ...   A Nand Kishore     BNJ Oxenford     NaN
# 632  633    2016  Bangalore  ...     AK Chaudhary  HDPK Dharmasena     NaN
# 633  634    2016      Delhi  ...        M Erasmus    C Shamshuddin     NaN
# 634  635    2016      Delhi  ...        M Erasmus        CK Nandan     NaN
# 635  636    2016  Bangalore  ...  HDPK Dharmasena     BNJ Oxenford     NaN
#
# [636 rows x 18 columns]
# ...

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (625, 17)

# %%
data["season"].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
data["season"].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2016    60
# 2010    60
# 2017    58
# 2008    58
# 2015    57
# 2009    57
# 2014    53
# Name: season, dtype: int64

# %%
#plotting d dataset in counter plot

sns.countplot(x=data["season"])

# %%
sns.countplot(y=data["season"])

# %%
plt.figure(figsize=(12,8))
sns.countplot(y=data["city"])

# %%
plt.hist(data["season"],edgecolor="Black")
plt.show()

# %%
d1=data["city"].value_counts().reset_index().rename(columns={"index":"city","city":"number of matches"})

# %%
d1
# Out:
#               city  number of matches
# 0           Mumbai                 85
# 1        Bangalore                 63
# 2          Kolkata                 61
# 3            Delhi                 59
# 4        Hyderabad                 49
# 5          Chennai                 48
# 6       Chandigarh                 46
# 7           Jaipur                 33
# 8             Pune                 32
# 9           Durban                 15
# 10       Centurion                 12
# 11       Ahmedabad                 12
# 12   Visakhapatnam                 11
# 13          Rajkot                 10
# 14      Dharamsala                  9
# 15    Johannesburg                  8
# 16  Port Elizabeth                  7
# 17       Abu Dhabi                  7
# 18          Ranchi                  7
# 19         Cuttack                  7
# 20       Cape Town                  7
# 21         Sharjah                  6
# 22          Raipur                  6
# 23          Indore                  5
# ...

# %%
plt.figure(figsize=(12,8))
sns.barplot(y="city",x="number of matches",data=d1)
plt.show()

# %%
# total maximum e=runs by wining

data["win_by_runs"].max()
# Out:
# 146

# %%
data[data["win_by_runs"]==146][["season","city","team1","team2","win_by_runs","winner"]]
# Out:
#     season   city  ... win_by_runs          winner
# 43    2017  Delhi  ...         146  Mumbai Indians
#
# [1 rows x 6 columns]

# %%
data
# Out:
#       id  season  ...          umpire1          umpire2
# 0      1    2017  ...      AY Dandekar         NJ Llong
# 1      2    2017  ...   A Nand Kishore           S Ravi
# 2      3    2017  ...      Nitin Menon        CK Nandan
# 3      4    2017  ...     AK Chaudhary    C Shamshuddin
# 5      6    2017  ...       A Deshmukh         NJ Llong
# ..   ...     ...  ...              ...              ...
# 631  632    2016  ...   A Nand Kishore     BNJ Oxenford
# 632  633    2016  ...     AK Chaudhary  HDPK Dharmasena
# 633  634    2016  ...        M Erasmus    C Shamshuddin
# 634  635    2016  ...        M Erasmus        CK Nandan
# 635  636    2016  ...  HDPK Dharmasena     BNJ Oxenford
#
# [625 rows x 17 columns]

# %%
data[data["toss_winner"]==data["winner"]][["season","city","team1","team2","toss_winner","winner"]]
# Out:
#      season  ...                       winner
# 1      2017  ...       Rising Pune Supergiant
# 2      2017  ...        Kolkata Knight Riders
# 3      2017  ...              Kings XI Punjab
# 5      2017  ...          Sunrisers Hyderabad
# 6      2017  ...               Mumbai Indians
# ..      ...  ...                          ...
# 629    2016  ...                Gujarat Lions
# 631    2016  ...  Royal Challengers Bangalore
# 632    2016  ...  Royal Challengers Bangalore
# 634    2016  ...          Sunrisers Hyderabad
# 635    2016  ...          Sunrisers Hyderabad
#
# [321 rows x 6 columns]

# %%
data["winner"].value_counts()
# Out:
# Mumbai Indians                 92
# Kolkata Knight Riders          77
# Chennai Super Kings            77
# Royal Challengers Bangalore    71
# Kings XI Punjab                69
# Rajasthan Royals               63
# Delhi Daredevils               61
# Sunrisers Hyderabad            40
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#replacing a name in dataset

data.replace({"Delhi Daredevils":"Delhi Capitals"},inplace=True)

# %%
data
# Out:
#       id  season  ...          umpire1          umpire2
# 0      1    2017  ...      AY Dandekar         NJ Llong
# 1      2    2017  ...   A Nand Kishore           S Ravi
# 2      3    2017  ...      Nitin Menon        CK Nandan
# 3      4    2017  ...     AK Chaudhary    C Shamshuddin
# 5      6    2017  ...       A Deshmukh         NJ Llong
# ..   ...     ...  ...              ...              ...
# 631  632    2016  ...   A Nand Kishore     BNJ Oxenford
# 632  633    2016  ...     AK Chaudhary  HDPK Dharmasena
# 633  634    2016  ...        M Erasmus    C Shamshuddin
# 634  635    2016  ...        M Erasmus        CK Nandan
# 635  636    2016  ...  HDPK Dharmasena     BNJ Oxenford
#
# [625 rows x 17 columns]

# %%
data["toss_winner"].value_counts()
# Out:
# Mumbai Indians                 83
# Kolkata Knight Riders          77
# Delhi Capitals                 71
# Kings XI Punjab                67
# Royal Challengers Bangalore    67
# Chennai Super Kings            66
# Rajasthan Royals               61
# Deccan Chargers                43
# Sunrisers Hyderabad            34
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
data["umpire2"].value_counts()
# Out:
# SJA Taufel         54
# C Shamshuddin      50
# S Ravi             47
# RJ Tucker          37
# CK Nandan          36
# RB Tiffin          30
# VA Kulkarni        27
# SK Tarapore        26
# BNJ Oxenford       25
# AM Saheba          23
# RE Koertzen        21
# M Erasmus          20
# DJ Harper          18
# AK Chaudhary       14
# HDPK Dharmasena    14
# NJ Llong           13
# K Srinath          13
# SL Shastri         13
# K Hariharan        11
# S Asnani           11
# CB Gaffaney        10
# VK Sharma           9
# BR Doctrove         8
# Nitin Menon         8
# PR Reiffel          8
# IL Howell           7
# RK Illingworth      7
# I Shivram           6
# GA Pratapkumar      6
# SS Hazare           6
# AL Hill             6
# A Nand Kishore      5
# TH Wijewardene      5
# PG Pathak           5
# S Das               5
# BG Jerling          4
# AV Jayaprakash      4
# A Deshmukh          3
# MR Benson           2
# K Srinivasan        2
# SD Ranade           2
# ...
